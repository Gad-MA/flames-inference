# %% [markdown]
# **Important Requirements**:
# * **GPU Runtime:** This notebook requires a GPU. Go to **Runtime > Change runtime type** and select **T4 GPU** (or better) before starting.
# * **Input Data:** Images must be in **NIfTI** format (`.nii.gz`).

# %%
# %%bash
#
# git clone https://github.com/Gad-MA/flames-inference.git
# cd "flames-inference"
# pip install -e .

# %%
# !mkdir input_images

# %% [markdown]
# Now upload all the images you want to segment to "input_images/"
#
# Make sure that all images follow the following naming format: `CASE_IDENTIFIER_0000.nii.gz`
#
# Example input image names:
# - `brain_001_0000.nii.gz`
# - `brain_002_0000.nii.gz`

# %%
# !export MPLBACKEND=Agg && \
flames-inference --input "input_images" --output "output_masks"
